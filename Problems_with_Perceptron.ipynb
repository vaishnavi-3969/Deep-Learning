# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi-3969/Deep-Learning/blob/main/Problems_with_Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1'] = [1,1,0,0]
or_data['input2'] = [1,0,1,0]
or_data['output'] = [1,1,1,0]

# %%
and_data['input1'] = [1,1,0,0]
and_data['input2'] = [1,0,1,0]
and_data['output'] = [1,0,0,0]

# %%
xor_data['input1'] = [1,1,0,0]
xor_data['input2'] = [1,0,1,0]
xor_data['output'] = [0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(
    and_data,
    x='input1',
    y='input2',
    hue='output',
    s=200
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(
    or_data,
    x='input1',
    y='input2',
    hue='output',
    s=200
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
sns.scatterplot(
    xor_data,
    x='input1',
    y='input2',
    hue='output',
    s=200
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from sklearn.linear_model import Perceptron
clf1 = Perceptron()
clf2 = Perceptron()
clf3 = Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf2.fit(or_data.iloc[:,0:2].values,or_data.iloc[:,-1].values)
clf3.fit(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x = np.linspace(-1,1,5)
y = -x + 1

# %%
plt.plot(x,y)
sns.scatterplot(
    and_data,
    x = 'input1',
    y = 'input2',
    hue='output',
    s=200
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
plt.plot(x,y)
sns.scatterplot(
    or_data,
    x = 'input1',
    y = 'input2',
    hue='output',
    s=200
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
plt.plot(x,y)
sns.scatterplot(
    xor_data,
    x = 'input1',
    y = 'input2',
    hue='output',
    s=200
)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>
